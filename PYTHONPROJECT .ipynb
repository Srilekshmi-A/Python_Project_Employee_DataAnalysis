# %% [markdown]
# #                                                             PYTHON PROJECT-Employee Dataset Analysis

# %% [markdown]
# #### Given a dataset of employees working in ABC company,consisting 458 rows and 9 columns.
# #### The company needs the detailed report and explanation of their employees in each team.

# %%
#IMPORTING NECSSSARY MODULES
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
# READING THE FILE
df=pd.read_csv('pythonprojectdata.csv')
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ##### The dataset contains 458 rows and 9 columns

# %% [markdown]
# #### Analysing and pre-processing dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
#CHECKING NULL VALUES
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ##### There are null values present in the columns "College" and "Salary".

# %%
#Changing null values to unknown
df.fillna("Unknown")
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     172     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     166     235
# 2     John Holland  Boston Celtics      30       SG   27     174     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     167     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ##### The null values are changed to 'Unknown'

# %%
#CHECKING DUPLICATE ENTRIES
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 453    False
# 454    False
# 455    False
# 456    False
# 457    False
# Length: 458, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### There are no duplicate entries in the dataset

# %%
#TO GET THE COLUMN NAMES
df.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight',
#        'College', 'Salary'],
#       dtype='object')

# %% [markdown]
# ##### The columns in the given dataset are: 'Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight','College' and 'Salary'

# %% [markdown]
# #### The column 'Height' is having incorrect data.

# %%
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %% [markdown]
# ##### The column 'Height' is having entries in the form of date

# %% [markdown]
# #### So changing that data  with any random numbers between 150 and 180

# %%
df['Height']=np.random.randint(150,180,size=458)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     172     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     166     235
# 2     John Holland  Boston Celtics      30       SG   27     174     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     155     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     170     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     164     203
# 454      Raul Neto       Utah Jazz      25       PG   24     179     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     167     256
# 456    Jeff Withey       Utah Jazz      24        C   26     170     231
# 457       Priyanka       Utah Jazz      34        C   25     167     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df['Height'].unique()
# Out:
# array([172, 166, 174, 155, 170, 168, 150, 179, 167, 160, 157, 165, 158,
#        175, 151, 159, 164, 163, 153, 156, 178, 161, 169, 173, 154, 171,
#        152, 162, 176, 177])

# %% [markdown]
# ##### These are the unique values in the 'Height' column

# %%
df['Height'].nunique()
# Out:
# 30

# %% [markdown]
# ##### There are 30 unique values in the 'Height' column (i.e. values between 150 and 180)

# %% [markdown]
# ## 1) How many are there in each Team and the percentage splitting with respect to the total employees?

# %%
count=df['Team'].value_counts()
percentage=round((count/sum(count)*100),2)
df1=pd.DataFrame({'Team':count.index,'Count':count.values,'percentage':percentage.values})
df1
# Out:
#                       Team  Count  percentage
# 0     New Orleans Pelicans     19        4.15
# 1        Memphis Grizzlies     18        3.93
# 2                Utah Jazz     16        3.49
# 3          New York Knicks     16        3.49
# 4          Milwaukee Bucks     16        3.49
# 5            Brooklyn Nets     15        3.28
# 6   Portland Trail Blazers     15        3.28
# 7    Oklahoma City Thunder     15        3.28
# 8           Denver Nuggets     15        3.28
# 9       Washington Wizards     15        3.28
# 10              Miami Heat     15        3.28
# 11       Charlotte Hornets     15        3.28
# 12           Atlanta Hawks     15        3.28
# 13       San Antonio Spurs     15        3.28
# 14         Houston Rockets     15        3.28
# 15          Boston Celtics     15        3.28
# 16          Indiana Pacers     15        3.28
# 17         Detroit Pistons     15        3.28
# 18     Cleveland Cavaliers     15        3.28
# ...

# %% [markdown]
# ##### The team with more number of employees is Team 'New Orleans Pelicans' with 19 employees making 4.15% of the total employees.
# ##### 'Orlando Magic'	and 'Minnesota Timberwolves' are the teams with least number of employees .Both team consists of 14 employees, each makes 3.06% .

# %% [markdown]
# ## 2) Segregate the employees with respect to different positions.

# %%
df['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# ##### There are 5 different employee positions : PG, SF, SG, PF & C

# %%
df['Position'].value_counts()
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %% [markdown]
# ##### These are the number of employees belonging to each position

# %%
df3=df.set_index('Position')
df3
# Out:
#                    Name            Team  Number  Age  Height  Weight  \
# Position
# PG        Avery Bradley  Boston Celtics       0   25     172     180
# SF          Jae Crowder  Boston Celtics      99   25     166     235
# SG         John Holland  Boston Celtics      30   27     174     205
# SG          R.J. Hunter  Boston Celtics      28   22     155     185
# PF        Jonas Jerebko  Boston Celtics       8   29     170     231
# ...                 ...             ...     ...  ...     ...     ...
# PG         Shelvin Mack       Utah Jazz       8   26     164     203
# PG            Raul Neto       Utah Jazz      25   24     179     179
# C          Tibor Pleiss       Utah Jazz      21   26     167     256
# C           Jeff Withey       Utah Jazz      24   26     170     231
# C              Priyanka       Utah Jazz      34   25     167     231
#
#                     College     Salary
# Position
# PG                    Texas  7730337.0
# ...

# %%
df3.sort_values(by="Position")
# Out:
#                      Name               Team  Number  Age  Height  Weight  \
# Position
# C                Priyanka          Utah Jazz      34   25     167     231
# C           Alan Williams       Phoenix Suns      15   23     176     260
# C          Tiago Splitter      Atlanta Hawks      11   31     152     245
# C          Walter Tavares      Atlanta Hawks      22   24     154     260
# C                Alex Len       Phoenix Suns      21   22     162     260
# ...                   ...                ...     ...  ...     ...     ...
# SG           Troy Daniels  Charlotte Hornets      30   24     177     205
# SG          Nicolas Batum  Charlotte Hornets       5   27     171     200
# SG           James Harden    Houston Rockets      13   26     151     220
# SG        Lamar Patterson      Atlanta Hawks      13   24     161     225
# SG        Khris Middleton    Milwaukee Bucks      22   24     164     234
#
#                         College      Salary
# Position
# ...

# %% [markdown]
# ##### This dataframe shows the details of employees grouped according to their position

# %%
a=df['Position'].value_counts()
plt.bar(a.index,a,color='lightseagreen',width=0.5)
plt.xlabel('Position')
plt.ylabel('Count of employees')
plt.title("Count of employees in each position")
plt.show()

# %% [markdown]
# ##### Most of the employees belong to Position 'SG' with 102 employees, followed by 100 employees in 'PF' .

# %% [markdown]
# # 3) Find from which age group most of the employees belong to.

# %%
ages=df['Age'].unique()
ages
# Out:
# array([25, 27, 22, 29, 21, 24, 20, 26, 28, 32, 23, 30, 33, 34, 37, 36, 31,
#        38, 39, 19, 35, 40], dtype=int64)

# %% [markdown]
# ##### The employees in the company  belongs to the age category 25 to 40

# %%
df['Age'].value_counts()
# Out:
# Age
# 24    47
# 25    46
# 27    41
# 23    41
# 26    36
# 28    31
# 30    31
# 29    28
# 22    26
# 31    22
# 20    19
# 21    19
# 33    14
# 32    13
# 34    10
# 36    10
# 35     9
# 37     4
# 38     4
# 40     3
# 39     2
# 19     2
# Name: count, dtype: int64

# %%
a=df['Age'].value_counts()
plt.bar(a.index,a,color='lightcoral',width=0.5)
plt.xlabel('Age')
plt.ylabel('Count of employees')
plt.title("Count of employees in each position")
plt.show()

# %% [markdown]
# ##### We can see that 47 people belongs to age group 24 ,46 people belongs to age group 25,41 people are of age group 27 and so on.
# ##### By analysing the top 10 maximum counts we can say that the majority of employees belongs to 22 to 30 age groups, with maximum from age group 24.

# %% [markdown]
# # 4) Find out under which team and position, spending in terms of salary is high.

# %%
df['Salary']
# Out:
# 0      7730337.0
# 1      6796117.0
# 2            NaN
# 3      1148640.0
# 4      5000000.0
#          ...
# 453    2433333.0
# 454     900000.0
# 455    2900000.0
# 456     947276.0
# 457     947276.0
# Name: Salary, Length: 458, dtype: float64

# %%
df['Salary'].max()
# Out:
# 25000000.0

# %% [markdown]
# ##### The highest salary in the company is 25000000

# %%
df.sort_values(by="Salary",ascending=False)
# Out:
#                 Name                    Team  Number Position  Age  Height  \
# 109      Kobe Bryant      Los Angeles Lakers      24       SF   37     166
# 169     LeBron James     Cleveland Cavaliers      23       SF   31     153
# 33   Carmelo Anthony         New York Knicks       7       SF   32     167
# 251    Dwight Howard         Houston Rockets      12        C   30     174
# 339       Chris Bosh              Miami Heat       1       PF   32     156
# ..               ...                     ...     ...      ...  ...     ...
# 273   Alex Stepheson       Memphis Grizzlies      35       PF   28     154
# 350    Briante Weber              Miami Heat      12       PG   23     175
# 353    Dorell Wright              Miami Heat      11       SF   30     167
# 397     Axel Toupane          Denver Nuggets       6       SG   23     161
# 409       Greg Smith  Minnesota Timberwolves       4       PF   25     155
#
#      Weight                College      Salary
# ...

# %% [markdown]
# ##### On sorting the Dataframe in descending order with respect to Salary  we can conclude that : Position 'SF' and Team ' Los Angeles Lakers' has the highest salary

# %% [markdown]
# # 5) Find if there is any correlation between age and salary , represent it visually

# %%
sns.scatterplot(x="Age", y="Salary", hue="Age", data=df)

plt.xlabel("Age")
plt.ylabel("Salary")
plt.title("age v/s salary")

plt.show()

# %% [markdown]
# ##### From this scatterplot we cannot say that there is a positive correlation between salary and age,as we can see in age group 35-40 salary is less mor majority of people.At the same time highest salary also belongs to age grop 35-40
# ##### In all the age groups,there are employees with minimum salary and they form majority of the employees.
# ##### So we can say that not only Age can determine the salary ,there can be many other factors also.

# %% [markdown]
# # Conclusion

# %% [markdown]
# ##### The   dataset of employees working in ABC company is preprocessed and analyzed.
# ##### Insights from the dataset are:
# ##### 1)  The team with more number of employees is Team 'New Orleans Pelicans' with 19 employees making 4.15% of the total employees.
# #####   'Orlando Magic' and 'Minnesota Timberwolves' are the teams with least number of employees .Both team consists of 14 employees, each makes 3.06%
# ##### 2)  Majority of the employees either belong to Positions  SG ,PF or,PG
# ##### 3)  Majority of employees are from 22 to 30 age group, with maximum from age group 24.
# ##### 4)  The employee with the highest salary belongs to  Position 'SF' and Team ' Los Angeles Lakers'.
# ##### 5)  We cannot determine the salary of a person by only considering their Age.There can also be many other factors that determine one's salary.
